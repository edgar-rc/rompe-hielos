// %%
import org.apache.spark.sql.functions._

// %%
val labels = spark.read.parquet("/Volumes/usr/rodolfolopez/hackathon/activation_labels.parquet")
val customers = spark.read.parquet("/Volumes/usr/rodolfolopez/hackathon/customers.parquet")
val events = spark.read.parquet("/Volumes/usr/rodolfolopez/hackathon/onboarding_events.parquet")

// %%
labels.printSchema()

// %%
customers.printSchema()

// %%
events.printSchema()

// %%
display(events.groupBy("step_name", "step_number").agg(count($"customer_id"),countDistinct($"customer_id")).orderBy("step_number"))
// Out:
// Databricks visualization. Run in Databricks to view.

// %%
display(events.groupBy("step_name", "step_number", "attempt_no").agg(count($"customer_id"),countDistinct($"customer_id")).orderBy("step_number"))

// %%
display(events)

// %%
display(labels)
